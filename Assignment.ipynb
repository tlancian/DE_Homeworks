# %%
#### LIBRARIES NEEDED ####

import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import time

# %%
#### FUNCTIONS ####


## Get Influenza's related words

def get_outlinks(url):
    '''This function takes the out links of a page given in url.
        /wiki is the starting tag of wikipedia pages
        PMID is the tag for counting the citations in a page (we are not interested about it)'''
    
    base_wiki_url = "https://it.wikipedia.org/wiki/"
    
    # Request the page
    page_response = requests.get(url)
    
    # Parse the page
    soup = BeautifulSoup(page_response.content, "html.parser")
    
    #Add out-links
    edges = []
    one_hop_links = []
    
    # Get neighbors of seed-url
    for link in soup.find_all('a'):
        temp = str(link.get('href'))
        if temp[0:5] == "/wiki" and "PMID" not in temp and ":" not in temp and "secolo" not in temp:
            try:
                int(temp[-4:])
            except:
                one_hop_links.append(temp[6:])
                edges.append(frozenset(["influenza", temp[6:]]))
    
    one_hop_links = list(set(one_hop_links))
    
    print(one_hop_links)
        
    for page in one_hop_links[:10]:
        
        url = base_wiki_url + page
        
        # Request the page
        page_response = requests.get(url)
        
        # Parse the page
        soup = BeautifulSoup(page_response.content, "html.parser")
        
        # Get neighbors of seed-url
        for link in soup.find_all('a'):
            temp = str(link.get('href'))
            if temp[0:5] == "/wiki" and "PMID" not in temp and ":" not in temp and "secolo" not in temp:
                try:
                    int(temp[-4:])
                except:
                    edges.append(frozenset([page, temp[6:]]))
    
    return edges

def get_data(words):
    
    if len(words) > 10:
        return print("No man, you can put just 10 words maximum")

    bs_url = "https://tools.wmflabs.org/pageviews/?project=it.wikipedia.org&platform=all-access&agent=user&range=all-time&pages="+"|".join(words)

    driver = webdriver.Chrome()
    driver.get(bs_url)
    
    time.sleep(10)

    first_click = driver.find_elements_by_tag_name("button")
    first_click[6].click()
    
    driver.find_element_by_class_name("download-csv").click()

# %% [markdown]
# # Pipeline

# %% [markdown]
# - Get Influenza's related words
# - Get Data and Ground Truth
# - Build Time Series
# - Measure Correlation
# - Model it!

# %% [markdown]
# ### Get Influenza's related words

# %% [markdown]
# Explain what we're going to do

# %%
# Starting Link
seed_url = "https://it.wikipedia.org/wiki/Influenza"

wiki_links = get_outlinks(seed_url)
# Out:
# ['Sindrome_di_Reye', 'Legionellosi', 'Naso', 'EMedicine', 'Sarcoidosi', 'Testa', 'Influenza_spagnola', 'Salasso', 'Fotofobia', 'Otite', 'Bronchiolite_obliterante', 'Istituto_Superiore_di_Sanit%C3%A0', 'Pneumomediastino', 'Rinite_allergica', 'Rinite_vasomotoria', 'Vaccino_influenza_stagionale', 'Virus_parainfluenzali_umani', 'Digital_object_identifier', 'Aspergillosi_broncopolmonare_allergica', 'Insufficienza_respiratoria', 'Organizzazione_Mondiale_della_Sanit%C3%A0', 'Berilliosi', 'Setto_nasale#Ematoma_del_setto_nasale', 'Antivirali', 'Bronchiectasia', 'Sindrome_di_Mendelson', 'Malattia_polmonare_restrittiva', 'Tonsille', 'Wendell_Stanley', 'Organizzazione_mondiale_della_sanit%C3%A0', 'Influenzavirus_C', 'Frank_Macfarlane_Burnet', 'Laringospasmo', 'Edema_polmonare', 'Reazioni_di_ipersensibilit%C3%A0#Ipersensibilit.C3.A0_di_Tipo_I_-_Tipo_anafilattico', 'Malattia_da_reflusso_faringo-laringeo', 'Tosse', 'Panbronchiolite_diffusa', 'Rinite_medicamentosa', 'Epiglottide', 'Polmonite_interstiziale_acuta', 'Rinite_atrofica', 'Interstiziopatia_polmonare', 'Inghilterra', 'Empiema_pleurico', 'Medicina_generale', 'Polmonite_da_ipersensibilit%C3%A0', 'Orthomyxoviridae', 'Fibrosi_da_bauxite', 'Azienda_farmaceutica', 'Ascesso_retrofaringeo', 'Influenza_di_Hong_Kong', 'Diabete', 'Emotorace', 'Rinite_non_allergica', 'Bronchite_cronica', 'Poliposi_naso-sinusale', 'Sindrome_di_L%C3%B6ffler', 'Virus_respiratorio_sinciziale_umano', 'Pleurite', 'Epidemiologia', 'Vaccino_influenzale', 'Artralgia', 'Nausea', 'Starnuto', 'Gemeinsame_Normdatei', 'Epatopatia', 'Seni_paranasali', 'Reazione_allergica', 'Influenza_aviaria', 'Asma', 'Pandemia', 'Sistema_immunitario', 'Polmonite_eosinofila', 'Ministero_della_Salute', 'Collo', 'Influenzavirus_A', 'Polmonite_atipica', 'Malattia', 'Faringite', 'Calicosi', 'New_Jersey', 'Pneumotorace', 'Influenza_suina', 'Tasso_di_mortalit%C3%A0', 'Proteinosi_alveolare_polmonare', 'Ozena', 'Tonsillite', 'Rinorrea', 'Ascesso_polmonare', 'Patologia', 'Oceano_Pacifico', 'Ultravioletto', 'Emisfero_boreale', 'Gastroenterite', 'Polmonite_interstiziale_non_specifica', 'Astrologia_occidentale', 'Emisfero_australe', 'Vomito', 'Influenzavirus_A_sottotipo_H1N1', 'Insufficienza_cardiaca', 'Artide', 'Laringite_cronica', 'Rinite', 'Bacteria', 'Talcosi', 'Reazione_a_catena_della_polimerasi', 'Virus_del_mosaico_del_tabacco', 'Enfisema', 'Tifo_esantematico', 'Febbre_suina', 'Cefalea', 'Sistema_respiratorio', 'Morbillo', 'Polmonite_interstiziale_desquamativa', 'Clamidia', 'SARS', 'Deviazione_del_setto_nasale', 'Effetto_collaterale_(medicina)', 'Febbre_tifoide', 'Fattore_di_rischio', 'Ascesso_peritonsillare', 'George_W._Bush', 'Perforazione_del_setto_nasale', 'Zoonosi', 'Peste_nera', 'Emoagglutinina', 'Noduli_vocali', 'Microscopio', 'Polmonite_ab_ingestis', 'Biblioteca_Nazionale_Centrale_di_Firenze', 'Rinascimento_italiano', 'ISBN', 'Chilotorace', 'Tracheite', 'Enciclopedia_Britannica', 'Polmonite_da_Mycoplasma', 'Laringite_acuta', 'Croup', 'International_Committee_on_Taxonomy_of_Viruses', 'Petecchia_(medicina)', 'Bronchite', 'Laringe', 'Bronchite_acuta', 'Emopneumotorace', 'Ipertensione_polmonare', 'Vaccino_antinfluenzale', 'Coronaropatia', 'Difterite', 'Etanolo', 'Amantadina', 'Silicosi', 'Pneumoconiosi', 'Baritosi', 'Cavit%C3%A0_pleurica', 'Epiglottite', 'Influenza', 'DNA_ricombinante', 'Scompenso_cardiaco', 'Italia', 'Influenza_asiatica', 'Ceppo_virale', 'Setto_nasale', 'Raffreddore_comune', 'Kansas', 'Contagio', 'Rinite_gravidica', 'Antracosi', 'H1N1', 'Pneumologia', 'Patogenesi', 'Embolia_polmonare', 'Rinite_difterica', 'Rinotracheite_virale_felina', 'Cina', 'Siderosi', 'Colera', 'Oseltamivir', 'Ipoclorito_di_sodio', 'Prima_guerra_mondiale', 'Internet_Archive', 'Antibiotico', 'Klebsiella', 'Dengue', 'Polymerase_chain_reaction', 'Mutazione', 'Asbestosi', 'H5N1', 'Paracetamolo', 'Sindrome_da_distress_respiratorio', 'Prodotto_interno_lordo', 'Pertosse', 'Inverno', 'Ammonio_quaternario', 'Sindrome_di_Caplan', 'Fibrosi_polmonare', 'Vitamina_D', 'A ...

# %%
wiki_links
# Out:
# [frozenset({'Microscopio', 'influenza'}),
#  frozenset({'Medicina_generale', 'influenza'}),
#  frozenset({'Pneumologia', 'influenza'}),
#  frozenset({'Malattia_infettiva', 'influenza'}),
#  frozenset({'Medical_Subject_Headings', 'influenza'}),
#  frozenset({'MedlinePlus', 'influenza'}),
#  frozenset({'EMedicine', 'influenza'}),
#  frozenset({'Malattia_infettiva', 'influenza'}),
#  frozenset({'Virus_a_RNA', 'influenza'}),
#  frozenset({'Orthomyxoviridae', 'influenza'}),
#  frozenset({'Febbre', 'influenza'}),
#  frozenset({'Rinorrea', 'influenza'}),
#  frozenset({'Mialgia', 'influenza'}),
#  frozenset({'Artralgia', 'influenza'}),
#  frozenset({'Cefalea', 'influenza'}),
#  frozenset({'Tosse', 'influenza'}),
#  frozenset({'Nausea', 'influenza'}),
#  frozenset({'Vomito', 'influenza'}),
#  frozenset({'Gastroenterite', 'influenza'}),
#  frozenset({'Polmonite', 'influenza'}),
#  frozenset({'Asma', 'influenza'}),
#  frozenset({'Scompenso_cardiaco', 'influenza'}),
#  frozenset({'Contagio', 'influenza'}),
#  frozenset({'Espettorato', 'influenza'}),
#  frozenset({'Reazione_a_catena_della_polimerasi', 'influenza'}),
#  frozenset({'Vaccino_antinfluenzale', 'influenza'}),
#  frozenset({'Organizzazione_Mondiale_della_Sanit%C3%A0', 'influenza'}),
#  frozenset({'Antivirali', 'influenza'}),
#  frozenset({'Oseltamivir', 'influenza'}),
#  frozenset({'Pandemia', 'influenza'}),
#  frozenset({'Influenza_spagnola', 'influenza'}),
#  frozenset({'Pandemia_influenzale', 'influenza'}),
#  frozenset({'Organizzazione_mondiale_della_sanit%C3%A0', 'influenza'}),
#  frozenset({'Influenzavirus_A_sottotipo_H1N1', 'influenza'}),
#  frozenset({'Astrologia_occidentale', 'influenza'}),
#  frozenset({'Dottrina_miasmatico-umorale', 'influenza'}),
#  frozenset({'Ippocrate_di_Coo', 'influenza'}),
#  frozenset({'Pandemia', 'influenza'}),
#  frozenset({'Difterite', 'influenza'}),
#  frozenset({'Febbre_tifoide', 'influenza'}),
#  frozenset({'Dengue', 'influenza'}),
#  frozenset({'Italia', 'influenza'}),
#  frozenset({'Salasso', 'influenza'}),
#  frozenset({'Rinascimento_italiano', 'influenza'}),
#  frozenset({'Influenza_spagnola', 'influenza'}),
#  frozenset({'Influenzavirus_A', 'influenza'}),
#  frozenset({'H1N1', 'influenza'}),
#  frozenset({'Cina', 'influenza'}),
#  frozenset({'Statunitensi', 'influenza'}),
#  frozenset({'Kansas', 'influenza'}),
#  frozenset({'Peste_nera', 'influenza'}),
#  frozenset({'Colera', 'influenza'}),
#  frozenset({'Tifo_esantematico', 'influenza'}),
#  frozenset({'Petecchia_(medicina)', 'influenza'}),
#  frozenset({'Edema_polmonare', 'influenza'}),
#  frozenset({'Artide', 'influenza'}),
#  frozenset({'Oceano_Pacifico', 'influenza'}),
#  frozenset({'Tasso_di_mortalit%C3%A0', 'influenza'}),
#  frozenset({'AIDS', 'influenza'}),
#  frozenset({'Ceppo_virale', 'influenza'}),
#  frozenset({'Antibiotico', 'influenza'}),
#  frozenset({'Pandemia_influenzale', 'influenza'}),
#  frozenset({'H1N1', 'influenza'}),
#  frozenset({'H1N1', 'influenza'}),
#  frozenset({'Eziologia', 'influenza'}),
#  frozenset({'Orthomyxoviridae', 'influenza'}),
#  frozenset({'Inghilterra', 'influenza'}),
#  frozenset({'Wendell_Stanley', 'influenza'}),
#  frozenset({'Virus_del_mosaico_del_tabacco', 'influenza'}),
#  frozenset({'Frank_Macfarlane_Burnet', 'influenza'}),
#  frozenset({'Universit%C3%A0_del_Michigan', 'influenza'}),
#  frozenset({'Vaccino_influenzale', 'influenza'}),
#  frozenset({'Prima_guerra_mondiale', 'influenza'}),
#  frozenset({'New_Jersey', 'influenza'}),
#  frozenset({'Patogenesi', 'influenza'}),
#  frozenset({'Epidemiologia', 'influenza'}),
#  frozenset({'Sequenziamento_del_DNA', 'influenza'}),
#  frozenset({'Genoma', 'influenza'}),
#  frozenset({'DNA_ricombinante', 'influenza'}),
#  frozenset({'Inverno', 'influenza'}),
#  frozenset({'Emisfero_boreale', 'influenza'}),
#  frozenset({'Emisfero_australe', 'influenza'}),
#  frozenset({'Morbillo', 'influenza'}),
#  frozenset({'Pertosse', 'influenza'}),
#  frozenset({'Vitamina_D', 'influenza'}),
#  frozenset({'Ultravioletto', 'influenza'}),
#  frozenset({'Prodotto_interno_lordo', 'influenza'}),
#  frozenset({'George_W._Bush', 'influenza'}),
#  frozenset({'Vietnam', 'influenza'}),
#  frozenset({'Organizzazione_mondiale_della_sanit%C3%A0', 'influenza'}),
#  frozenset({'Istituto_Superiore_di_Sanit%C3%A0', 'influenza'}),
#  frozenset({'Italia', 'influenza'}),
#  frozenset({'Ministero_della_Salute', 'influenza'}),
#  frozenset({'International_Committee_on_Taxonomy_of_Viruses', 'influenza'}),
#  frozenset({'Influenzavirus_A', 'influenza'}),
#  frozenset({'Influenzavirus_C', 'influenza'}),
#  frozenset({'Emoagglutinina', 'influenza'}),
#  frozenset({'Neuraminidasi', 'influenza'}),
#  frozenset({'Influenzavirus_A', 'influenza'}),
#  frozenset({'Influenza_spagnola', 'influenza'}),
#  frozenset({'Influenza_asiatica', 'influenza'}),
#  frozenset({'Influenza_di_Hong_Kong', 'influenza'}),
#  frozenset({'Influenza_aviaria', 'influenza'}),
#  frozenset({'Zoonosi', 'influenza'}),
#  frozenset({'Febbre_suina', 'influenza'}),
#  frozenset({'Pinnipedia', 'influenza'}),
#  frozenset({'Mutazione', 'influenza'}),
#  frozenset({'Pandemia', 'influenza'}),
#  frozenset({'Bacteria', 'influenza'}),
#  frozenset({'Faringite', 'influenza'}),
#  frozenset({'Tonsillite', 'influenza'}),
#  frozenset({'Raffreddore_comune', 'influenza'}),
#  frozenset({'Febbre', 'influenza'}),
#  frozenset({'Cefalea', 'influenza'}),
#  frozenset({'Starnuto', 'influenza'}),
#  frozenset({'Tosse', 'influenza'}),
#  frozenset({'Fotofobia', 'influenza'}),
#  frozenset({'Polmonite', 'influenza'}),
#  frozenset({'Organizzazione_mondiale_della_sanit%C3%A0', 'influenza'}),
#  frozenset({'Bronchite', 'influenza'}),
#  frozenset({'Seni_paranasali', 'influenza'}),
#  frozenset({'Otite', 'influenza'}),
#  frozenset({'Coronaropatia', 'influenza'}),
#  frozenset({'Insufficienza_cardiaca', 'influenza'}),
#  frozenset({'Fattore_di_rischio', 'influenza'}),
#  frozenset({'Polymerase_chain_reaction', 'influenza'}),
#  frozenset({'Virus_respiratorio_sinciziale_umano', 'influenza'}),
#  frozenset({'Virus_parainfluenzali_umani', 'influenza'}),
#  frozenset({'Paracetamolo', 'influenza'}),
#  frozenset({'Epatopatia', 'influenza'}),
#  frozenset({'Aspirina', 'influenza'}),
#  frozenset({'Aspirina', 'influenza'}),
#  frozenset({'Sindrome_di_Reye', 'influenza'}),
#  frozenset({'Oseltamivir', 'influenza'}),
#  frozenset({'Zanamivir', 'influenza'}),
#  frozenset({'Amantadina', 'influenza'}),
#  frozenset({'Etanolo', 'influenza'}),
#  frozenset({'Ammonio_quaternario', 'influenza'}),
#  frozenset({'Ipoclorito_di_sodio', 'influenza'}),
#  frozenset({'Vaccino_influenza_stagionale', 'influenza'}),
#  frozenset({'Sistema_immunitario', 'influenza'}),
#  frozenset({'Effetto_collaterale_(medicina)', 'influenza'}),
#  frozenset({'Reazione_allergica', 'influenza'}),
#  frozenset({'Azienda_farmaceutica', 'influenza'}),
#  frozenset({'Diabete', 'influenza'}),
#  frozenset({'Neoplasia', 'influenza'}),
#  frozenset({'Contagio', 'influenza'}),
#  frozenset({'Malattia', 'influenza'}),
#  frozenset({'Influenza_aviaria', 'influenza'}),
#  frozenset({'Influenza_suina', 'influenza'}),
#  frozenset({'Rinotracheite_virale_felina', 'influenza'}),
#  frozenset({'Influenza_aviaria', 'influenza'}),
#  frozenset({'H5N1', 'influenza'}),
#  frozenset({'ISBN', 'influenza'}),
#  frozenset({'Digital_object_identifier', 'influenza'}),
#  frozenset({'Digital_object_identifier', 'influenza'}),
#  frozenset({'Digital_object_identifier', 'influenza'}),
#  frozenset({'Digital_object_identifier', 'influenza'}),
#  frozenset({'ISBN', 'influenza'}),
#  frozenset({'Internet_Archive', 'influenza'}),
#  frozenset({'Internet_Archive', 'influenza'}),
#  frozenset({'Internet_Archive', 'influenza'}),
#  frozenset({'Internet_Archive', 'influenza'}),
#  frozenset({'Digital_object_identifier', 'influenza'}),
#  frozenset({'ISBN', 'influenza'}),
#  frozenset({'Digital_object_identifier', 'influenza'}),
#  frozenset({'Internet_Archive', 'influenza'}),
#  frozenset({'Digital_object_identifier', 'influenza'}),
#  frozenset({'Internet_Archive', 'influenza'}),
#  frozenset({'ISBN', 'influenza'}),
#  frozenset({'Dizionario_storico_della_Svizzera', 'influenza'}),
#  frozenset({'Biblioteca_Nazionale_Centrale_di_Firenze', 'influenza'}),
#  frozenset({'Enciclopedia_Britannica', 'influenza'}),
#  frozenset({'Patologia', 'influenza'}),
#  frozenset({'Sistema_respiratorio', 'influenza'}),
#  frozenset({'Raffreddore_comune', 'influenza'}),
#  frozenset({'Testa', 'influenza'}),
#  frozenset({'Seni_paranasali', 'influenza'}),
#  frozenset({'Sinusite', 'influenza'}),
#  frozenset({'Naso', 'influenza'}),
#  frozenset({'Rinite', 'influenza'}),
#  frozenset({'Rinite_vasomotoria', 'influenza'}),
#  frozenset({'Ozena', 'influenza'}),
#  frozenset({'Rinite_allergica', 'influenza'}),
#  frozenset({'Rinite_atrofica', 'influenza'}),
#  frozenset({'Rinite_difterica', 'influenza'}),
#  frozenset({'Rinite_gravidica', 'influenza'}),
#  frozenset({'Rinite_medicamentosa', 'influenza'}),
#  frozenset({'Rinite_non_allergica', 'influenza'}),
#  frozenset({'Poliposi_naso-sinusale', 'influenza'}),
#  frozenset({'Rinorrea', 'influenza'}),
#  frozenset({'Setto_nasale', 'influenza'}),
#  frozenset({'Deviazione_del_setto_nasale', 'influenza'}),
#  frozenset({'Perforazione_del_setto_nasale', 'influenza'}),
#  frozenset({'Setto_nasale#Ematoma_del_setto_nasale', 'influenza'}),
#  frozenset({'Tonsille', 'influenza'}),
#  frozenset({'Tonsillite', 'influenza'}),
#  frozenset({'Ascesso_peritonsillare', 'influenza'}),
#  frozenset({'Collo', 'influenza'}),
#  frozenset({'Faringe', 'influenza'}),
#  frozenset({'Faringite', 'influenza'}),
#  frozenset({'Faringite_streptococcica', 'influenza'}),
#  frozenset({'Malattia_da_reflusso_faringo-laringeo', 'influenza'}),
#  frozenset({'Ascesso_retrofaringeo', 'influenza'}),
#  frozenset({'Laringe', 'influenza'}),
#  frozenset({'Croup', 'influenza'}),
#  frozenset({'Laringite_acuta', 'influenza'}),
#  frozenset({'Laringite_cronica', 'influenza'}),
#  frozenset({'Malattia_da_reflusso_faringo-laringeo', 'influenza'}),
#  frozenset({'Laringospasmo', 'influenza'}),
#  frozenset({'Corde_vocali', 'influenza'}),
#  frozenset({'Malattia_da_reflusso_faringo-laringeo', 'influenza'}),
#  frozenset({'Noduli_vocali', 'influenza'}),
#  frozenset({'Epiglottide', 'influenza'}),
#  frozenset({'Epiglottite', 'influenza'}),
#  frozenset({'Trachea', 'influenza'}),
#  frozenset({'Tracheite', 'influenza'}),
#  frozenset({'Bronco', 'influenza'}),
#  frozenset({'Bronchite_acuta', 'influenza'}),
#  frozenset({'Broncopneumopatia_cronica_ostruttiva', 'influenza'}),
#  frozenset({'Bronchite_cronica', 'influenza'}),
#  frozenset({'Enfisema', 'influenza'}),
#  frozenset({'Asma', 'influenza'}),
#  frozenset({'Bronchiectasia', 'influenza'}),
#  frozenset({'Bronchite', 'influenza'}),
#  frozenset({'Bronchiolite', 'influenza'}),
#  frozenset({'Bronchiolite_obliterante', 'influenza'}),
#  frozenset({'Panbronchiolite_diffusa', 'influenza'}),
#  frozenset({'Interstiziopatia_polmonare', 'influenza'}),
#  frozenset({'Malattia_polmonare_restrittiva', 'influenza'}),
#  frozenset({'Fibrosi_polmonare', 'influenza'}),
#  frozenset({'Malattia_professionale', 'influenza'}),
#  frozenset({'Pneumoconiosi', 'influenza'}),
#  frozenset({'Asbestosi', 'influenza'}),
#  frozenset({'Baritosi', 'influenza'}),
#  frozenset({'Fibrosi_da_bauxite', 'influenza'}),
#  frozenset({'Berilliosi', 'influenza'}),
#  frozenset({'Sindrome_di_Caplan', 'influenza'}),
#  frozenset({'Calicosi', 'influenza'}),
#  frozenset({'Antracosi', 'influenza'}),
#  frozenset({'Siderosi', 'influenza'}),
#  frozenset({'Silicosi', 'influenza'}),
#  frozenset({'Talcosi', 'influenza'}),
#  frozenset({'Polmonite_da_ipersensibilit%C3%A0', 'influenza'}),
#  frozenset({'Sindrome_da_distress_respiratorio', 'influenza'}),
#  frozenset({'Edema_polmonare', 'influenza'}),
#  frozenset({'Sindrome_di_L%C3%B6ffler', 'influenza'}),
#  frozenset({'Polmonite_eosinofila', 'influenza'}),
#  frozenset({'Reazioni_di_ipersensibilit%C3%A0#Ipersensibilit.C3.A0_di_Tipo_I_-_Tipo_anafilattico',
#             'influenza'}),
#  frozenset({'Aspergillosi_broncopolmonare_allergica', 'influenza'}),
#  frozenset({'Polmonite_interstiziale_acuta', 'influenza'}),
#  frozenset({'Fibrosi_polmonare_idiopatica', 'influenza'}),
#  frozenset({'Sarcoidosi', 'influenza'}),
#  frozenset({'Polmonite', 'influenza'}),
#  frozenset({'Pneumococco', 'influenza'}),
#  frozenset({'Klebsiella', 'influenza'}),
#  frozenset({'Polmonite_atipica', 'influenza'}),
#  frozenset({'Polmonite_da_Mycoplasma', 'influenza'}),
#  frozenset({'Legionellosi', 'influenza'}),
#  frozenset({'Clamidia', 'influenza'}),
#  frozenset({'Sindrome_di_Mendelson', 'influenza'}),
#  frozenset({'Polmonite_ab_ingestis', 'influenza'}),
#  frozenset({'Polmoniti_interstiziali_idiopatiche', 'influenza'}),
#  frozenset({'Polmonite_interstiziale_desquamativa', 'influenza'}),
#  frozenset({'Bronchiolite_obliterante_-_polmonite_in_organizzazione',
#             'influenza'}),
#  frozenset({'Polmonite_interstiziale_non_specifica', 'influenza'}),
#  frozenset({'Atelectasia', 'influenza'}),
#  frozenset({'Ipertensione_polmonare', 'influenza'}),
#  frozenset({'Embolia_polmonare', 'influenza'}),
#  frozenset({'Ascesso_polmonare', 'influenza'}),
#  frozenset({'Cavit%C3%A0_pleurica', 'influenza'}),
#  frozenset({'Mediastino', 'influenza'}),
#  frozenset({'Pleurite', 'influenza'}),
#  frozenset({'Pneumotorace', 'influenza'}),
#  frozenset({'Emopneumotorace', 'influenza'}),
#  frozenset({'Versamento_pleurico', 'influenza'}),
#  frozenset({'Emotorace', 'influenza'}),
#  frozenset({'Idrotorace', 'influenza'}),
#  frozenset({'Chilotorace', 'influenza'}),
#  frozenset({'Empiema_pleurico', 'influenza'}),
#  frozenset({'Fibrotorace', 'influenza'}),
#  frozenset({'Mediastinite', 'influenza'}),
#  frozenset({'Pneumomediastino', 'influenza'}),
#  frozenset({'Insufficienza_respiratoria', 'influenza'}),
#  frozenset({'SARS', 'influenza'}),
#  frozenset({'Proteinosi_alveolare_polmonare', 'influenza'}),
#  frozenset({'Library_of_Congress_Control_Number', 'influenza'}),
#  frozenset({'Gemeinsame_Normdatei', 'influenza'}),
#  frozenset({'Influenza', 'influenza'}),
#  frozenset({'Influenza', 'influenza'}),
#  frozenset({'Pagina_principale', 'influenza'}),
#  frozenset({'Pagina_principale', 'influenza'}),
#  frozenset({'Fegato', 'Sindrome_di_Reye'}),
#  frozenset({'Neurologia', 'Sindrome_di_Reye'}),
#  frozenset({'Medical_Subject_Headings', 'Sindrome_di_Reye'}),
#  frozenset({'MedlinePlus', 'Sindrome_di_Reye'}),
#  frozenset({'EMedicine', 'Sindrome_di_Reye'}),
#  frozenset({'Malattia', 'Sindrome_di_Reye'}),
#  frozenset({'Cervello', 'Sindrome_di_Reye'}),
#  frozenset({'Fegato', 'Sindrome_di_Reye'}),
#  frozenset({'Encefalopatia', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Steatosi_epatica'}),
#  frozenset({'Acido_acetilsalicilico', 'Sindrome_di_Reye'}),
#  frozenset({'Patogenesi', 'Sindrome_di_Reye'}),
#  frozenset({'Metabolismo', 'Sindrome_di_Reye'}),
#  frozenset({'Mitocondrio', 'Sindrome_di_Reye'}),
#  frozenset({'Aspirina', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Virus_(biologia)'}),
#  frozenset({'Sindrome_di_Reye', 'Steatosi_epatica'}),
#  frozenset({'Encefalopatia', 'Sindrome_di_Reye'}),
#  frozenset({'Edema_cerebrale', 'Sindrome_di_Reye'}),
#  frozenset({'Rene', 'Sindrome_di_Reye'}),
#  frozenset({'Ittero', 'Sindrome_di_Reye'}),
#  frozenset({'Diagnosi', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Sistema_nervoso_centrale'}),
#  frozenset({'Epatomegalia', 'Sindrome_di_Reye'}),
#  frozenset({'Letargia', 'Sindrome_di_Reye'}),
#  frozenset({'Convulsioni', 'Sindrome_di_Reye'}),
#  frozenset({'Paralisi', 'Sindrome_di_Reye'}),
#  frozenset({'Febbre', 'Sindrome_di_Reye'}),
#  frozenset({'Diagnosi_differenziale', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Sistema_nervoso_centrale'}),
#  frozenset({'Segno_(medicina)', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Sintomo'}),
#  frozenset({'Epidemiologia', 'Sindrome_di_Reye'}),
#  frozenset({'Acido_acetilsalicilico', 'Sindrome_di_Reye'}),
#  frozenset({'Modello_animale', 'Sindrome_di_Reye'}),
#  frozenset({'Mitocondrio', 'Sindrome_di_Reye'}),
#  frozenset({'Paesi_sviluppati', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Studio_clinico#Studi_osservazionali'}),
#  frozenset({'Centers_for_Disease_Control_and_Prevention', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Stati_Uniti_d%27America'}),
#  frozenset({'Food_and_Drug_Administration', 'Sindrome_di_Reye'}),
#  frozenset({'Regno_Unito', 'Sindrome_di_Reye'}),
#  frozenset({'Malattia_di_Kawasaki', 'Sindrome_di_Reye'}),
#  frozenset({'Antiaggregante', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Trombosi'}),
#  frozenset({'Sindrome_di_Reye', 'Varicella'}),
#  frozenset({'Influenza', 'Sindrome_di_Reye'}),
#  frozenset({'Razza_caucasica', 'Sindrome_di_Reye'}),
#  frozenset({'Mediana_(statistica)', 'Sindrome_di_Reye'}),
#  frozenset({'Anamnesi_(medicina)', 'Sindrome_di_Reye'}),
#  frozenset({'Alanina_transaminasi', 'Sindrome_di_Reye'}),
#  frozenset({'Meningite', 'Sindrome_di_Reye'}),
#  frozenset({'Encefalite', 'Sindrome_di_Reye'}),
#  frozenset({'Cambridge_University_Press', 'Sindrome_di_Reye'}),
#  frozenset({'ISBN', 'Sindrome_di_Reye'}),
#  frozenset({'Digital_object_identifier', 'Sindrome_di_Reye'}),
#  frozenset({'Digital_object_identifier', 'Sindrome_di_Reye'}),
#  frozenset({'Digital_object_identifier', 'Sindrome_di_Reye'}),
#  frozenset({'PubMed', 'Sindrome_di_Reye'}),
#  frozenset({'Acido_acetilsalicilico', 'Sindrome_di_Reye'}),
#  frozenset({'Patologia', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Sistema_nervoso'}),
#  frozenset({'Sindrome_di_Reye', 'Sistema_nervoso_centrale'}),
#  frozenset({'Infiammazione', 'Sindrome_di_Reye'}),
#  frozenset({'Cervello', 'Sindrome_di_Reye'}),
#  frozenset({'Encefalite', 'Sindrome_di_Reye'}),
#  frozenset({'Encefalite_limbica', 'Sindrome_di_Reye'}),
#  frozenset({'Encefalite_letargica', 'Sindrome_di_Reye'}),
#  frozenset({'Midollo_spinale', 'Sindrome_di_Reye'}),
#  frozenset({'Poliomielite', 'Sindrome_di_Reye'}),
#  frozenset({'Mielite_trasversa', 'Sindrome_di_Reye'}),
#  frozenset({'Encefalomielite', 'Sindrome_di_Reye'}),
#  frozenset({'Encefalomielite_acuta_disseminata', 'Sindrome_di_Reye'}),
#  frozenset({'Encefalomielite_mialgica', 'Sindrome_di_Reye'}),
#  frozenset({'Meningoencefalite', 'Sindrome_di_Reye'}),
#  frozenset({'Cervello', 'Sindrome_di_Reye'}),
#  frozenset({'Encefalopatia', 'Sindrome_di_Reye'}),
#  frozenset({'Malattie_neurodegenerative', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Sistema_extrapiramidale'}),
#  frozenset({'Disordini_del_movimento', 'Sindrome_di_Reye'}),
#  frozenset({'Parkinsonismi', 'Sindrome_di_Reye'}),
#  frozenset({'Malattia_di_Parkinson', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Sindrome_neurolettica_maligna'}),
#  frozenset({'Neurodegenerazione_associata_alla_pantotenato_chinasi',
#             'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Taupatie'}),
#  frozenset({'Paralisi_sopranucleare_progressiva', 'Sindrome_di_Reye'}),
#  frozenset({'Atrofia_multi-sistemica', 'Sindrome_di_Reye'}),
#  frozenset({'Emiballismo', 'Sindrome_di_Reye'}),
#  frozenset({'Malattia_di_Huntington', 'Sindrome_di_Reye'}),
#  frozenset({'Discinesia', 'Sindrome_di_Reye'}),
#  frozenset({'Distonia', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Meige', 'Sindrome_di_Reye'}),
#  frozenset({'Blefarospasmo', 'Sindrome_di_Reye'}),
#  frozenset({'Atetosi', 'Sindrome_di_Reye'}),
#  frozenset({'Corea_(medicina)', 'Sindrome_di_Reye'}),
#  frozenset({'Coreoatetosi', 'Sindrome_di_Reye'}),
#  frozenset({'Mioclono', 'Sindrome_di_Reye'}),
#  frozenset({'Acatisia', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Tremore'}),
#  frozenset({'Sindrome_di_Reye', 'Tremore_essenziale'}),
#  frozenset({'Sindrome_delle_gambe_senza_riposo', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_dell%27uomo_rigido', 'Sindrome_di_Reye'}),
#  frozenset({'Demenza', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Taupatie'}),
#  frozenset({'Malattia_di_Alzheimer', 'Sindrome_di_Reye'}),
#  frozenset({'Afasia_primaria_progressiva', 'Sindrome_di_Reye'}),
#  frozenset({'Demenza_frontotemporale', 'Sindrome_di_Reye'}),
#  frozenset({'Malattia_di_Pick', 'Sindrome_di_Reye'}),
#  frozenset({'Demenza_a_corpi_di_Lewy', 'Sindrome_di_Reye'}),
#  frozenset({'Demenza_vascolare', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_da_deplezione_del_DNA_mitocondriale',
#             'Sindrome_di_Reye'}),
#  frozenset({'Sclerosi_multipla', 'Sindrome_di_Reye'}),
#  frozenset({'Malattia_di_Devic', 'Sindrome_di_Reye'}),
#  frozenset({'Adrenoleucodistrofia', 'Sindrome_di_Reye'}),
#  frozenset({'Malattia_di_Alexander', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Canavan', 'Sindrome_di_Reye'}),
#  frozenset({'Malattia_di_Krabbe', 'Sindrome_di_Reye'}),
#  frozenset({'Leucodistrofia_metacromatica', 'Sindrome_di_Reye'}),
#  frozenset({'Mielinolisi_pontina_centrale', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Alpers', 'Sindrome_di_Reye'}),
#  frozenset({'Epilessia', 'Sindrome_di_Reye'}),
#  frozenset({'Crisi_parziale_semplice', 'Sindrome_di_Reye'}),
#  frozenset({'Crisi_convulsive_toniche_e_crisi_convulsive_cloniche',
#             'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Stato_epilettico'}),
#  frozenset({'Sindrome_di_Janz', 'Sindrome_di_Reye'}),
#  frozenset({'Mal_di_testa', 'Sindrome_di_Reye'}),
#  frozenset({'Cefalea', 'Sindrome_di_Reye'}),
#  frozenset({'Emicrania_emiplegica_familiare', 'Sindrome_di_Reye'}),
#  frozenset({'Cefalea_a_grappolo', 'Sindrome_di_Reye'}),
#  frozenset({'Cefalea_di_tipo_tensivo', 'Sindrome_di_Reye'}),
#  frozenset({'Malattie_cerebrovascolari', 'Sindrome_di_Reye'}),
#  frozenset({'Attacco_ischemico_transitorio', 'Sindrome_di_Reye'}),
#  frozenset({'Amaurosi_fugace', 'Sindrome_di_Reye'}),
#  frozenset({'Amnesia_globale_transitoria', 'Sindrome_di_Reye'}),
#  frozenset({'Afasia', 'Sindrome_di_Reye'}),
#  frozenset({'Ictus_cerebrale', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Foville', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Millard-Gubler', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Sindrome_di_Wallenberg'}),
#  frozenset({'Sindrome_di_Reye', 'Sindrome_di_Weber'}),
#  frozenset({'Insonnia', 'Sindrome_di_Reye'}),
#  frozenset({'Ipersonnia', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_delle_apnee_nel_sonno', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_delle_apnee_ostruttive_nel_sonno', 'Sindrome_di_Reye'}),
#  frozenset({'Ipoventilazione_alveolare_primitiva', 'Sindrome_di_Reye'}),
#  frozenset({'Narcolessia', 'Sindrome_di_Reye'}),
#  frozenset({'Catalessi', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Kleine-Levin', 'Sindrome_di_Reye'}),
#  frozenset({'Disturbi_del_ritmo_circadiano', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_da_sonno_anticipato', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_da_sonno_posticipato', 'Sindrome_di_Reye'}),
#  frozenset({'Eccessiva_sonnolenza_diurna', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_da_ciclo_sonno-veglia_alterato', 'Sindrome_di_Reye'}),
#  frozenset({'Jet_lag', 'Sindrome_di_Reye'}),
#  frozenset({'Liquido_cerebrospinale', 'Sindrome_di_Reye'}),
#  frozenset({'Ipertensione_intracranica', 'Sindrome_di_Reye'}),
#  frozenset({'Idrocefalo', 'Sindrome_di_Reye'}),
#  frozenset({'Idrocefalo_normoteso', 'Sindrome_di_Reye'}),
#  frozenset({'Ipertensione_intracranica_idiopatica', 'Sindrome_di_Reye'}),
#  frozenset({'Edema_cerebrale', 'Sindrome_di_Reye'}),
#  frozenset({'Encefalopatia_epatica', 'Sindrome_di_Reye'}),
#  frozenset({'Midollo_spinale', 'Sindrome_di_Reye'}),
#  frozenset({'Mielopatia', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Siringomielia'}),
#  frozenset({'Sindrome_di_Reye', 'Siringobulbia'}),
#  frozenset({'Malattie_neurodegenerative', 'Sindrome_di_Reye'}),
#  frozenset({'Atassia_spinocerebellare', 'Sindrome_di_Reye'}),
#  frozenset({'Atassia_di_Friedreich', 'Sindrome_di_Reye'}),
#  frozenset({'Atassia-teleangectasia', 'Sindrome_di_Reye'}),
#  frozenset({'Malattia_del_motoneurone', 'Sindrome_di_Reye'}),
#  frozenset({'Neurone_motorio_superiore', 'Sindrome_di_Reye'}),
#  frozenset({'Sclerosi_laterale_primaria', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye', 'Sindrome_pseudobulbare'}),
#  frozenset({'Paraparesi_spastica_ereditaria', 'Sindrome_di_Reye'}),
#  frozenset({'Neurone_motorio_superiore', 'Sindrome_di_Reye'}),
#  frozenset({'Atrofia_muscolare_spinale', 'Sindrome_di_Reye'}),
#  frozenset({'Atrofia_muscolare_progressiva', 'Sindrome_di_Reye'}),
#  frozenset({'Sclerosi_laterale_amiotrofica', 'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye'}),
#  frozenset({'Sindrome_di_Reye'}),
#  frozenset({'Pagina_principale', 'Sindrome_di_Reye'}),
#  frozenset({'Pagina_principale', 'Sindrome_di_Reye'}),
#  frozenset({'Legionellosi', 'Microscopio_elettronico_a_trasmissione'}),
#  frozenset({'Legionella_pneumophila', 'Legionellosi'}),
#  frozenset({'Infettivologia', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Pneumologia'}),
#  frozenset({'Legionellosi', 'Medical_Subject_Headings'}),
#  frozenset({'Legionellosi', 'MedlinePlus'}),
#  frozenset({'EMedicine', 'Legionellosi'}),
#  frozenset({'Infezione', 'Legionellosi'}),
#  frozenset({'Batterio', 'Legionellosi'}),
#  frozenset({'Legionella', 'Legionellosi'}),
#  frozenset({'Legionella_pneumophila', 'Legionellosi'}),
#  frozenset({'Apparato_respiratorio', 'Legionellosi'}),
#  frozenset({'Febbre_di_Pontiac', 'Legionellosi'}),
#  frozenset({'American_Legion', 'Legionellosi'}),
#  frozenset({'Aerosol', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Streptococcus_pneumoniae'}),
#  frozenset({'Haemophilus_influenzae', 'Legionellosi'}),
#  frozenset({'Febbre_di_Pontiac', 'Legionellosi'}),
#  frozenset({'Alte_vie_respiratorie', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Pilo_(biologia)'}),
#  frozenset({'Fagocitosi', 'Legionellosi'}),
#  frozenset({'AIDS', 'Legionellosi'}),
#  frozenset({'Glucocorticoidi', 'Legionellosi'}),
#  frozenset({'Ascessi', 'Legionellosi'}),
#  frozenset({'Fibrina', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Macrofagi'}),
#  frozenset({'Legionellosi', 'Neutrofili'}),
#  frozenset({'Legionellosi', 'Polmonite_atipica'}),
#  frozenset({'Cefalea', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Mialgia'}),
#  frozenset({'Emoftoe', 'Legionellosi'}),
#  frozenset({'Dolore_addominale', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Nausea'}),
#  frozenset({'Legionellosi', 'Vomito'}),
#  frozenset({'Diarrea', 'Legionellosi'}),
#  frozenset({'Febbre_di_Pontiac', 'Legionellosi'}),
#  frozenset({'Febbre_di_Pontiac', 'Legionellosi'}),
#  frozenset({'Astenia', 'Legionellosi'}),
#  frozenset({'Cefalea', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Tosse'}),
#  frozenset({'Legionellosi', 'Nausea'}),
#  frozenset({'Legionellosi', 'Milza'}),
#  frozenset({'Fegato', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Rene'}),
#  frozenset({'Legionellosi', 'Sinusite'}),
#  frozenset({'Legionellosi', 'Peritonite'}),
#  frozenset({'Legionellosi', 'Pielonefrite'}),
#  frozenset({'Cellulite_(infezione)', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Pancreatite'}),
#  frozenset({'Iponatriemia', 'Legionellosi'}),
#  frozenset({'Ematuria', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Trombocitopenia'}),
#  frozenset({'Legionellosi', 'Radiografia'}),
#  frozenset({'Legionellosi', 'Torace'}),
#  frozenset({'Colorazione_di_Gram', 'Legionellosi'}),
#  frozenset({'Coltura', 'Legionellosi'}),
#  frozenset({'Agar_agar', 'Legionellosi'}),
#  frozenset({'Immunofluorescenza', 'Legionellosi'}),
#  frozenset({'Chlamydia_pneumoniae', 'Legionellosi'}),
#  frozenset({'Chlamydia_psittaci', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Mycoplasma_pneumoniae'}),
#  frozenset({'Coxiella_burnetii', 'Legionellosi'}),
#  frozenset({'Eritromicina', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Macrolidi'}),
#  frozenset({'Azitromicina', 'Legionellosi'}),
#  frozenset({'Claritromicina', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Roxitromicina'}),
#  frozenset({'Josamicina', 'Legionellosi'}),
#  frozenset({'Chinoloni', 'Legionellosi'}),
#  frozenset({'Ciprofloxacina', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Ofloxacina'}),
#  frozenset({'Legionellosi', 'Pefloxacina'}),
#  frozenset({'Legionellosi', 'Rifampicina'}),
#  frozenset({'Legionellosi', 'Mortalit%C3%A0'}),
#  frozenset({'Ionizzazione', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Rame'}),
#  frozenset({'Argento', 'Legionellosi'}),
#  frozenset({'Iperclorazione', 'Legionellosi'}),
#  frozenset({'ISBN', 'Legionellosi'}),
#  frozenset({'Digital_object_identifier', 'Legionellosi'}),
#  frozenset({'Harrison_-_Principi_di_medicina_interna', 'Legionellosi'}),
#  frozenset({'ISBN', 'Legionellosi'}),
#  frozenset({'Legionella', 'Legionellosi'}),
#  frozenset({'Legionella_pneumophila', 'Legionellosi'}),
#  frozenset({'Febbre_di_Pontiac', 'Legionellosi'}),
#  frozenset({'Legionellosi', 'Polmonite'}),
#  frozenset({'Legionellosi'}),
#  frozenset({'Legionellosi'}),
#  frozenset({'Legionellosi', 'Pagina_principale'}),
#  frozenset({'Legionellosi', 'Pagina_principale'}),
#  frozenset({'Naso', 'Naso_(disambigua)'}),
#  frozenset({'Naso', 'Simmetria'}),
#  frozenset({'Naso', 'Viso'}),
#  frozenset({'Faringe', 'Naso'}),
#  frozenset({'Laringe', 'Naso'}),
#  frozenset({'Apparato_respiratorio', 'Naso'}),
#  frozenset({'Naso', 'Splancnocranio'}),
#  frozenset({'Naso', 'Volto'}),
#  frozenset({'Naso', 'Piramide'}),
#  frozenset({'Naso', 'Uomo'}),
#  frozenset({'Naso', 'Naso#Tipologie_di_naso'}),
#  frozenset({'Diametro', 'Naso'}),
#  frozenset({'Cute', 'Naso'}),
#  frozenset({'Naso', 'Osso'}),
#  frozenset({'Naso', 'Osso_frontale'}),
#  frozenset({'Mascella', 'Naso'}),
#  frozenset({'Cartilagine', 'Naso'}),
#  frozenset({'Naso', 'Triangolo'}),
#  frozenset({'Collagene', 'Naso'}),
#  frozenset({'Naso', 'Setto_nasale'}),
#  frozenset({'Arteria', 'Naso'}),
#  frozenset({'Arteria_mascellare_interna', 'Naso'}),
#  frozenset({'Naso', 'Vena_giugulare_interna'}),
#  frozenset({'Naso', 'Vaso_linfatico'}),
#  frozenset({'Linfonodo', 'Naso'}),
#  frozenset({'Muscoli', 'Naso'}),
#  frozenset({'Cute', 'Naso'}),
#  frozenset({'Naso', 'Tessuto_fibroso'}),
#  frozenset({'Naso', 'Osso_lacrimale'}),
#  frozenset({'Naso', 'Osso_palatino'}),
#  frozenset({'Naso', 'Osso_lacrimale'}),
#  frozenset({'Naso', 'Osso_etmoide'}),
#  frozenset({'Naso', 'Nervo_olfattivo'}),
#  frozenset({'Naso', 'Vomere_(anatomia)'}),
#  frozenset({'Mucosa', 'Naso'}),
#  frozenset({'Naso', 'Nervo_profondo_petroso'}),
#  frozenset({'Naso', 'Nervo_grande_petroso'}),
#  frozenset({'Naso', 'Ottaviano_Augusto'}),
#  frozenset({'Naso', 'Socrate'}),
#  frozenset({'Becco', 'Naso'}),
#  frozenset({'Aquila', 'Naso'}),
#  frozenset({'Dante_Alighieri', 'Naso'}),
#  frozenset({'Naso', 'Venere_di_Milo'}),
#  frozenset({'Naso', 'Ottaviano_Augusto'}),
#  frozenset({'Naso', 'Socrate'}),
#  frozenset({'Dante_Alighieri', 'Naso'}),
#  frozenset({'Naso', 'Olfatto'}),
#  frozenset({'Naso', 'Rinite'}),
#  frozenset({'Naso', 'Raffreddore_comune'}),
#  frozenset({'Naso', 'Rinofaringite'}),
#  frozenset({'Naso', 'Rinofima'}),
#  frozenset({'Naso', 'Rinorragia'}),
#  frozenset({'Naso', 'Rinorrea'}),
#  frozenset({'Naso', 'Rinoigrometro'}),
#  frozenset({'Naso', 'Rinoplastica'}),
#  frozenset({'Cartilagini_accessorie_del_naso', 'Naso'}),
#  frozenset({'Cartilagine_alare_maggiore', 'Naso'}),
#  frozenset({'Cartilagine_del_setto', 'Naso'}),
#  frozenset({'Cartilagine_laterale', 'Naso'}),
#  frozenset({'Naso', 'Sanguinamento_del_naso'}),
#  frozenset({'Fronte_(anatomia)', 'Naso'}),
#  frozenset({'Naso', 'Osso'}),
#  frozenset({'Naso', 'Odore'}),
#  frozenset({'Naso', 'Osso_etmoide'}),
#  frozenset({'Naso', 'Osso_frontale'}),
#  frozenset({'Naso', 'Osso_lacrimale'}),
#  frozenset({'Naso', 'Osso_mascellare'}),
#  frozenset({'Naso', 'Osso_nasale'}),
#  frozenset({'Naso', 'Osso_palatino'}),
#  frozenset({'Naso', 'Osso_sfenoide'}),
#  frozenset({'Naso', 'Rinoplastica'}),
#  frozenset({'Naso', 'Settoplastica'}),
#  frozenset({'Naso', 'Tessuto_cartilagineo'}),
#  frozenset({'Naso', 'Tessuto_osseo'}),
#  frozenset({'Naso', 'Vomere_(anatomia)'}),
#  frozenset({'Istituto_dell%27Enciclopedia_Italiana', 'Naso'}),
#  frozenset({'Biblioteca_Nazionale_Centrale_di_Firenze', 'Naso'}),
#  frozenset({'Enciclopedia_Britannica', 'Naso'}),
#  frozenset({'Anatomia_umana', 'Naso'}),
#  frozenset({'Naso', 'Testa'}),
#  frozenset({'Collo', 'Naso'}),
#  frozenset({'Cranio', 'Naso'}),
#  frozenset({'Fronte_(anatomia)', 'Naso'}),
#  frozenset({'Naso', 'Occhio'}),
#  frozenset({'Naso', 'Orecchio'}),
#  frozenset({'Bocca', 'Naso'}),
#  frozenset({'Lingua_(anatomia)', 'Naso'}),
#  frozenset({'Dente', 'Naso'}),
#  frozenset({'Mandibola', 'Naso'}),
#  frozenset({'Naso', 'Viso'}),
#  frozenset({'Guancia', 'Naso'}),
#  frozenset({'Mento', 'Naso'}),
#  frozenset({'Naso', 'Torso'}),
#  frozenset({'Naso', 'Spalla'}),
#  frozenset({'Colonna_vertebrale', 'Naso'}),
#  frozenset({'Mammella', 'Naso'}),
#  frozenset({'Capezzolo', 'Naso'}),
#  frozenset({'Naso', 'Torace'}),
#  frozenset({'Gabbia_toracica', 'Naso'}),
#  frozenset({'Cuore_umano', 'Naso'}),
#  frozenset({'Naso', 'Polmone_umano'}),
#  frozenset({'Addome_(anatomia)', 'Naso'}),
#  frozenset({'Naso', 'Quadranti_e_regioni_addominali'}),
#  frozenset({'Naso', 'Ombelico'}),
#  frozenset({'Bacino_(anatomia)', 'Naso'}),
#  frozenset({'Apparato_genitale', 'Naso'}),
#  frozenset({'Clitoride', 'Naso'}),
#  frozenset({'Naso', 'Vagina'}),
#  frozenset({'Naso', 'Pene'}),
#  frozenset({'Naso', 'Scroto'}),
#  frozenset({'Naso', 'Testicolo'}),
#  frozenset({'Anca', 'Naso'}),
#  frozenset({'Ano', 'Naso'}),
#  frozenset({'Naso', 'Natiche'}),
#  frozenset({'Arto_superiore', 'Naso'}),
#  frozenset({'Braccio', 'Naso'}),
#  frozenset({'Gomito', 'Naso'}),
#  frozenset({'Avambraccio', 'Naso'}),
#  frozenset({'Naso', 'Polso'}),
#  frozenset({'Mano', 'Naso'}),
#  frozenset({'Dito', 'Naso'}),
#  frozenset({'Naso', 'Pollice_(dito)'}),
#  frozenset({'Indice_(dito)', 'Naso'}),
#  frozenset({'Dito_medio', 'Naso'}),
#  frozenset({'Anulare', 'Naso'}),
#  frozenset({'Mignolo', 'Naso'}),
#  frozenset({'Arto_inferiore', 'Naso'}),
#  frozenset({'Coscia', 'Naso'}),
#  frozenset({'Ginocchio', 'Naso'}),
#  frozenset({'Gamba', 'Naso'}),
#  frozenset({'Naso', 'Polpaccio'}),
#  frozenset({'Caviglia', 'Naso'}),
#  frozenset({'Naso', 'Tallone'}),
#  frozenset({'Naso', 'Piede'}),
#  frozenset({'Dito', 'Naso'}),
#  frozenset({'Alluce', 'Naso'}),
#  frozenset({'Naso', 'Pelle'}),
#  frozenset({'Capelli', 'Naso'}),
#  frozenset({'Cuoio_capelluto', 'Naso'}),
#  frozenset({'Gemeinsame_Normdatei', 'Naso'}),
#  frozenset({'Naso'}),
#  frozenset({'Naso'}),
#  frozenset({'Naso', 'Pagina_principale'}),
#  frozenset({'Naso', 'Pagina_principale'}),
#  frozenset({'Base_di_dati', 'EMedicine'}),
#  frozenset({'EMedicine', 'On-line'}),
#  frozenset({'EMedicine', 'Pediatria'}),
#  frozenset({'EMedicine', 'Endocrinologia'}),
#  frozenset({'EMedicine', 'Genetica'}),
#  frozenset({'Cardiologia', 'EMedicine'}),
#  frozenset({'EMedicine', 'Pneumologia'}),
#  frozenset({'EMedicine', 'Internet_Archive'}),
#  frozenset({'EMedicine', 'ISBN'}),
#  frozenset({'EMedicine'}),
#  frozenset({'EMedicine'}),
#  frozenset({'EMedicine', 'Pagina_principale'}),
#  frozenset({'EMedicine', 'Pagina_principale'}),
#  frozenset({'Ematologia', 'Sarcoidosi'}),
#  frozenset({'Dermatologia', 'Sarcoidosi'}),
#  frozenset({'Pneumologia', 'Sarcoidosi'}),
#  frozenset({'Oftalmologia', 'Sarcoidosi'}),
#  frozenset({'Mendelian_Inheritance_in_Man', 'Sarcoidosi'}),
#  frozenset({'Medical_Subject_Headings', 'Sarcoidosi'}),
#  frozenset({'MedlinePlus', 'Sarcoidosi'}),
#  frozenset({'EMedicine', 'Sarcoidosi'}),
#  frozenset({'Ernest_Henri_Besnier', 'Sarcoidosi'}),
#  frozenset({'Lingua_greca', 'Sarcoidosi'}),
#  frozenset({'Malattia', 'Sarcoidosi'}),
#  frozenset({'Idiopatica', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Tessuti_connettivi'}),
#  frozenset({'Granuloma', 'Sarcoidosi'}),
#  frozenset({'Fattore_di_crescita_trasformante_beta', 'Sarcoidosi'}),
#  frozenset({'Linfonodi', 'Sarcoidosi'}),
#  frozenset({'Organo_(anatomia)', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Sistema_immunitario'}),
#  frozenset({'Infezione', 'Sarcoidosi'}),
#  frozenset({'Antigene', 'Sarcoidosi'}),
#  frozenset({'Farmaco', 'Sarcoidosi'}),
#  frozenset({'Calcitriolo', 'Sarcoidosi'}),
#  frozenset({'Ipercalcemia', 'Sarcoidosi'}),
#  frozenset({'Interferone_gamma', 'Sarcoidosi'}),
#  frozenset({'Linfociti', 'Sarcoidosi'}),
#  frozenset({'Macrofagi', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Sintesi_chimica'}),
#  frozenset({'Sarcoidosi', 'Sintomi'}),
#  frozenset({'Anti-infiammatori', 'Sarcoidosi'}),
#  frozenset({'Ibuprofene', 'Sarcoidosi'}),
#  frozenset({'Aspirina', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Steroidi'}),
#  frozenset({'Prednisone', 'Sarcoidosi'}),
#  frozenset({'Prednisolone', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Tumore'}),
#  frozenset({'Sarcoidosi', 'Sistema_immunitario'}),
#  frozenset({'Metotressato', 'Sarcoidosi'}),
#  frozenset({'Azatioprina', 'Sarcoidosi'}),
#  frozenset({'Leflunomide', 'Sarcoidosi'}),
#  frozenset({'Mortalit%C3%A0', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Stati_Uniti'}),
#  frozenset({'Sarcoidosi', 'Scandinavia'}),
#  frozenset({'Islanda', 'Sarcoidosi'}),
#  frozenset({'Afroamericano', 'Sarcoidosi'}),
#  frozenset({'Giappone', 'Sarcoidosi'}),
#  frozenset({'Cuore_umano', 'Sarcoidosi'}),
#  frozenset({'Paesi_in_via_di_sviluppo', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Tubercolosi'}),
#  frozenset({'Europea', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Scandinavi'}),
#  frozenset({'Ottocento', 'Sarcoidosi'}),
#  frozenset({'Novecento', 'Sarcoidosi'}),
#  frozenset({'Gotta', 'Sarcoidosi'}),
#  frozenset({'Insufficienza_renale', 'Sarcoidosi'}),
#  frozenset({'Calcio_(elemento)', 'Sarcoidosi'}),
#  frozenset({'Ernest_Henri_Besnier', 'Sarcoidosi'}),
#  frozenset({'Oculista', 'Sarcoidosi'}),
#  frozenset({'Congiuntiva', 'Sarcoidosi'}),
#  frozenset({'Parotite', 'Sarcoidosi'}),
#  frozenset({'Linfoma_di_Hodgkin', 'Sarcoidosi'}),
#  frozenset({'Eritema_nodoso', 'Sarcoidosi'}),
#  frozenset({'Artrite', 'Sarcoidosi'}),
#  frozenset({'Linfoadenopatia', 'Sarcoidosi'}),
#  frozenset({'Ilo_(anatomia)', 'Sarcoidosi'}),
#  frozenset({'Polmoni', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Sindrome_di_L%C3%B6fgren'}),
#  frozenset({'Incidenza_(epidemiologia)', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Svezia'}),
#  frozenset({'Islanda', 'Sarcoidosi'}),
#  frozenset({'Regno_Unito', 'Sarcoidosi'}),
#  frozenset({'Prevalenza_(epidemiologia)', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Stati_Uniti'}),
#  frozenset({'Europoide', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Sud_America'}),
#  frozenset({'Sarcoidosi', 'Spagna'}),
#  frozenset({'India', 'Sarcoidosi'}),
#  frozenset({'Canada', 'Sarcoidosi'}),
#  frozenset({'Filippine', 'Sarcoidosi'}),
#  frozenset({'Malattia_celiaca', 'Sarcoidosi'}),
#  frozenset({'Grecia', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Spagna'}),
#  frozenset({'Sarcoidosi', 'Screening'}),
#  frozenset({'Sarcoidosi', 'Vigili_del_fuoco'}),
#  frozenset({'Pesticidi', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Silice'}),
#  frozenset({'Antipertensivi', 'Sarcoidosi'}),
#  frozenset({'Infiammazione', 'Sarcoidosi'}),
#  frozenset({'Organo_(anatomia)', 'Sarcoidosi'}),
#  frozenset({'Polmoni', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Sintomi'}),
#  frozenset({'Astenia', 'Sarcoidosi'}),
#  frozenset({'Artrite', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Xeroftalmia'}),
#  frozenset({'Fotofobia', 'Sarcoidosi'}),
#  frozenset({'Dispnea', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Tosse'}),
#  frozenset({'Emottisi', 'Sarcoidosi'}),
#  frozenset({'Eruzioni_cutanee', 'Sarcoidosi'}),
#  frozenset({'Eritema_nodoso', 'Sarcoidosi'}),
#  frozenset({'Nervo_faciale', 'Sarcoidosi'}),
#  frozenset({'Linfoadenopatia', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Sindrome_di_L%C3%B6fgren'}),
#  frozenset({'Prognosi', 'Sarcoidosi'}),
#  frozenset({'Alveolo_polmonare', 'Sarcoidosi'}),
#  frozenset({'Ipertensione_polmonare', 'Sarcoidosi'}),
#  frozenset({'Laringe', 'Sarcoidosi'}),
#  frozenset({'Faringe', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Seni_paranasali'}),
#  frozenset({'Afroamericano', 'Sarcoidosi'}),
#  frozenset({'Cute', 'Sarcoidosi'}),
#  frozenset({'Cuoio_capelluto', 'Sarcoidosi'}),
#  frozenset({'Cuore_umano', 'Sarcoidosi'}),
#  frozenset({'Autopsia', 'Sarcoidosi'}),
#  frozenset({'Aritmia', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Uveite'}),
#  frozenset({'Retina', 'Sarcoidosi'}),
#  frozenset({'Cecit%C3%A0', 'Sarcoidosi'}),
#  frozenset({'Parotite', 'Sarcoidosi'}),
#  frozenset({'Nervo_faciale', 'Sarcoidosi'}),
#  frozenset({'Febbre', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Sclera'}),
#  frozenset({'Sarcoidosi', 'Sistema_nervoso'}),
#  frozenset({'Nervi_cranici', 'Sarcoidosi'}),
#  frozenset({'Paralisi', 'Sarcoidosi'}),
#  frozenset({'Nervo_faciale', 'Sarcoidosi'}),
#  frozenset({'Nervo_ottico', 'Sarcoidosi'}),
#  frozenset({'Papilledema', 'Sarcoidosi'}),
#  frozenset({'Ipotalamo', 'Sarcoidosi'}),
#  frozenset({'Ipofisi', 'Sarcoidosi'}),
#  frozenset({'Meningite', 'Sarcoidosi'}),
#  frozenset({'Neuropatia_periferica', 'Sarcoidosi'}),
#  frozenset({'Mielopatia', 'Sarcoidosi'}),
#  frozenset({'Midollo_spinale', 'Sarcoidosi'}),
#  frozenset({'Prognosi', 'Sarcoidosi'}),
#  frozenset({'Diabete_insipido', 'Sarcoidosi'}),
#  frozenset({'Ciclo_mestruale', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Temperatura_corporea'}),
#  frozenset({'Sarcoidosi', 'Umore'}),
#  frozenset({'Prolattina', 'Sarcoidosi'}),
#  frozenset({'Prolattina', 'Sarcoidosi'}),
#  frozenset({'Amenorrea', 'Sarcoidosi'}),
#  frozenset({'Galattorrea', 'Sarcoidosi'}),
#  frozenset({'Mastite', 'Sarcoidosi'}),
#  frozenset({'Metabolita', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Vitamina_D'}),
#  frozenset({'Rene', 'Sarcoidosi'}),
#  frozenset({'Ipercalcemia', 'Sarcoidosi'}),
#  frozenset({'Interferone_gamma', 'Sarcoidosi'}),
#  frozenset({'Calcitriolo', 'Sarcoidosi'}),
#  frozenset({'Ipercalciuria', 'Sarcoidosi'}),
#  frozenset({'Calcio_(elemento)', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Urine'}),
#  frozenset({'Ipercalcemia', 'Sarcoidosi'}),
#  frozenset({'Sangue', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Tiroide'}),
#  frozenset({'Parotide', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Xerostomia'}),
#  frozenset({'Apparato_gastrointestinale', 'Sarcoidosi'}),
#  frozenset({'Fegato', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Stomaco'}),
#  frozenset({'Intestino', 'Sarcoidosi'}),
#  frozenset({'Autopsia', 'Sarcoidosi'}),
#  frozenset({'Malattia_di_Crohn', 'Sarcoidosi'}),
#  frozenset({'Pancreas', 'Sarcoidosi'}),
#  frozenset({'Rene', 'Sarcoidosi'}),
#  frozenset({'Clearance', 'Sarcoidosi'}),
#  frozenset({'Creatinina', 'Sarcoidosi'}),
#  frozenset({'Epididimo', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Testicoli'}),
#  frozenset({'Prostata', 'Sarcoidosi'}),
#  frozenset({'Ovaie', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Tube_di_Falloppio'}),
#  frozenset({'Sarcoidosi', 'Utero'}),
#  frozenset({'Sarcoidosi', 'Vulva'}),
#  frozenset({'Sarcoidosi', 'Sterilit%C3%A0'}),
#  frozenset({'Epatomegalia', 'Sarcoidosi'}),
#  frozenset({'Ittero', 'Sarcoidosi'}),
#  frozenset({'Linfopenia', 'Sarcoidosi'}),
#  frozenset({'Anemia', 'Sarcoidosi'}),
#  frozenset({'Leucopenia', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Trombocitopenia'}),
#  frozenset({'Anemia_emolitica', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Splenomegalia'}),
#  frozenset({'Midollo_osseo', 'Sarcoidosi'}),
#  frozenset({'Cellule_T', 'Sarcoidosi'}),
#  frozenset({'Monocitosi', 'Sarcoidosi'}),
#  frozenset({'Fosfatasi', 'Sarcoidosi'}),
#  frozenset({'Allergie', 'Sarcoidosi'}),
#  frozenset({'Ipergammaglobulinemia', 'Sarcoidosi'}),
#  frozenset({'Linfoadenopatia', 'Sarcoidosi'}),
#  frozenset({'Linfonodi', 'Sarcoidosi'}),
#  frozenset({'Milza', 'Sarcoidosi'}),
#  frozenset({'Microscopio', 'Sarcoidosi'}),
#  frozenset({'Broncoscopia', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Tomografia_a_emissione_di_positroni'}),
#  frozenset({'Radiografia', 'Sarcoidosi'}),
#  frozenset({'Linfoadenopatia', 'Sarcoidosi'}),
#  frozenset({'Ilo_(anatomia)', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Sindrome_di_L%C3%B6fgren'}),
#  frozenset({'Lavaggio_broncoalveolare', 'Sarcoidosi'}),
#  frozenset({'Corticosteroide', 'Sarcoidosi'}),
#  frozenset({'Prednisone', 'Sarcoidosi'}),
#  frozenset({'Metotrexate', 'Sarcoidosi'}),
#  frozenset({'Azatioprina', 'Sarcoidosi'}),
#  frozenset({'Melatonina', 'Sarcoidosi'}),
#  frozenset({'Idrossiclorochina', 'Sarcoidosi'}),
#  frozenset({'Ciclosporina', 'Sarcoidosi'}),
#  frozenset({'Immunosoppressore', 'Sarcoidosi'}),
#  frozenset({'Enzima_di_conversione_dell%27angiotensina', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Tomografia_a_emissione_di_positroni'}),
#  frozenset({'Sarcoidosi', 'Tomografia_computerizzata'}),
#  frozenset({'Milza', 'Sarcoidosi'}),
#  frozenset({'Fegato', 'Sarcoidosi'}),
#  frozenset({'Fibrosi_polmonare', 'Sarcoidosi'}),
#  frozenset({'Diagnosi', 'Sarcoidosi'}),
#  frozenset({'Prognosi', 'Sarcoidosi'}),
#  frozenset({'Corticosteroidi', 'Sarcoidosi'}),
#  frozenset({'Sarcoidosi', 'Tumore'}),
#  frozenset({'Sarcoidosi', 'Tumore_del_polmone'}),
#  frozenset({'Linfoma', 'Sarcoidosi'}),
#  frozenset({'Linfoma_non-Hodgkin', 'Sarcoidosi'}),
#  frozenset({'Leucemia_a_cellule_capellute', 'Sarcoidosi'}),
#  frozenset({'Leucemia_mieloide_acuta', 'Sarcoidosi'}),
#  frozenset({'Leucemia_mieloblastica_acuta', 'Sarcoidosi'}),
#  frozenset({'ISBN', 'Sarcoidosi'}),
#  frozenset({'American_Journal_of_Respiratory_and_Critical_Care_Medicine',
#             'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'PubMed', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'PubMed', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'ISBN', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'American_Journal_of_Respiratory_and_Critical_Care_Medicine',
#             'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'PubMed', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'ISBN', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'PubMed', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'PubMed', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'ISBN', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'ISSN', 'Sarcoidosi'}),
#  frozenset({'PubMed', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'PubMed', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'PubMed', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  frozenset({'Digital_object_identifier', 'Sarcoidosi'}),
#  ...]

# %%
a = [frozenset([4,5]),frozenset([4,5]),frozenset([5,6])]

# %%
set(a)
# Out:
# {frozenset({5, 6}), frozenset({4, 5})}
